# %%
from home_security.data.minio import Minio
from PIL import Image
import logging

logging.basicConfig(level=logging.INFO)

# %%
minio = Minio(endpoint="localhost:9000", access_key='homesecurity', secret_key='homesecuritybyjohn', secure=False)
# Out:
# INFO:Minio-client:Successfully connected to Minio client

# %%
image = Image.open('../images/old_images/rectory/A03-1_20240605102007.jpg')

# %%
image_id = minio.add_image(image=image, bucket_name='test-bucket')
# Out:
# INFO:Minio-client:Added 4fe61f31-ad40-452b-89c9-69f986897ca6 to test-bucket

# %%
minio.get_image(bucket_name='test-bucket', image_uuid=image_id)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=352x288>

# %%
minio.remove_image(image_uuid=image_id, bucket_name='test-bucket')
# Out:
# True
